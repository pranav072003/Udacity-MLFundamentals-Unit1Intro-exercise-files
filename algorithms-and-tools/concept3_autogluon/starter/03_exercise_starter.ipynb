# %% [markdown]
# # Exercise: AutoGluon

# %% [markdown]
# ![todd-quackenbush-IClZBVw5W5A-unsplash.jpg](attachment:d1438680-e1a7-4d9a-afe3-10a406f7de63.jpg)

# %% [markdown]
# Throughout this lesson, you've been trying different models on the same two datasets, wine and diabetes. Now, we're going to try our hand at accelerating this methodology by using AutoGluon. In this exercise, train two different AutonGluon models and see how they compare to previous iterations in exercise 1 and 2.
#
# You're tasked with completing the following steps:
# 1. Load in the wine dataset from scikit learn.
# 2. For the wine dataset, create a train and test split, 80% train / 20% test.
# 3. Create a AutoGluon Classifier model with these hyper parameters:
#     1. time_limit: 120
#     2. presets: best_quality
# 4. Output the model table summary
# 5. Evaluate the trained model on the test dataset
# 6. Load the diabetes dataset from scikit learn
# 7. For the Diabetes dataset, create a train and test split, 80% train / 20% test.
# 8. Create a AutoGluon Regression model with these hyper parameters:
#     1. eval_metric: r2
#     2. time_limit: 120
#     3. presets: best_quality
# 9. Output the model table summary
# 10. Evaluate the trained model on the test dataset

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Open up Sagemaker Studio

# %% [markdown]
# 1. Notebook should be using a `ml.t3.medium` instance (2 vCPU + 4 GiB)
# 2. Notebook should be using kernal: `Python 3 (MXNet 1.8 Python 3.7 CPU Optimized)`

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0" bokeh==2.0.1
# !pip install autogluon --no-cache-dir

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.metrics import r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# ## AutoGluon Classifier

# %%
# Load in the wine dataset
wine = datasets.load_wine()
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the wine `data` dataset as a dataframe and name the columns with `feature_names`
df = pd.DataFrame(wine["data"], columns=wine["feature_names"])

# Include the target as well
df["target"] = wine["target"]

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
df_train, df_test = train_test_split(df, test_size=0.2, random_state=0)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a classifier, autogluon will pick it up
predictor = TabularPredictor(label="target").fit(
    train_data=df_train, time_limit=120, presets="best_quality"
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210619_215608/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "AutogluonModels/ag-20210619_215608/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    142
# Train Data Columns: 13
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [2, 1, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6050.17 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.84s of the 119.84s of remaining time.
# 	0.662	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.71s of the 119.7s of remaining time.
# 	0.7113	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 119.56s of the 119.55s of remaining time.
# No improvement since epoch 7: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# 	0.9859	 = Validation accuracy score
# 	7.07s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 112.31s of the 112.31s of remaining time.
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# 	0.9859	 = Validation accuracy score
# 	3.1s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 109.15s of the 109.15s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.97s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 108.14s of the 108.13s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	0.72s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 107.29s of the 107.29s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.86s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 106.31s of the 106.31s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	1.34s	 = Training runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 104.95s of the 104.94s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 104.16s of the 104.15s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 103.37s of the 103.37s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	0.68s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 102.57s of the 102.57s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	7.46s	 = Training runtime
# 	0.48s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 94.57s of the 94.57s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	2.57s	 = Training runtime
# 	0.01s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 91.89s of the 91.88s of remaining time.
# 	0.662	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 91.88s of the 91.87s of remaining time.
# 	0.7113	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 91.87s of the 91.86s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# 	0.9859	 = Validation accuracy score
# 	11.86s	 = Training runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 86.92s of the 86.91s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	3.75s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 86.25s of the 86.24s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	2.07s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 84.93s of the 84.93s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	0.72s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 84.92s of the 84.91s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.86s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 84.91s of the 84.91s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	2.55s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 83.68s of the 83.67s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 83.67s of the 83.66s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 83.66s of the 83.65s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	1.45s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 82.77s of the 82.76s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	12.99s	 = Training runtime
# 	0.98s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 76.68s of the 76.67s of remaining time.
# 	0.9577	 = Validation accuracy score
# 	5.42s	 = Training runtime
# 	0.02s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 73.77s of the 73.76s of remaining time.
# 	0.662	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 73.76s of the 73.75s of remaining time.
# 	0.7113	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 73.75s of the 73.74s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# 	0.9859	 = Validation accuracy score
# 	16.99s	 = Training runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 68.43s of the 68.43s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	4.59s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 67.55s of the 67.54s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	3.16s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 66.42s of the 66.41s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	0.72s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 66.41s of the 66.4s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.86s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 66.4s of the 66.39s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	4.43s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 64.46s of the 64.45s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 64.44s of the 64.44s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 64.42s of the 64.41s of remaining time.
# 	0.9718	 = Validation accuracy score
# 	2.52s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 63.19s of the 63.19s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	17.87s	 = Training runtime
# 	1.41s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 57.83s of the 57.83s of remaining time.
# 	0.9648	 = Validation accuracy score
# 	7.5s	 = Training runtime
# 	0.04s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 55.69s of the 55.69s of remaining time.
# 	0.662	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 55.68s of the 55.67s of remaining time.
# 	0.7113	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 55.67s of the 55.67s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 1: early stopping
# 	0.9859	 = Validation accuracy score
# 	21.79s	 = Training runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 50.72s of the 50.71s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	5.43s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 49.84s of the 49.84s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	4.23s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 48.74s of the 48.73s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	0.72s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 48.73s of the 48.72s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.86s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 48.72s of the 48.71s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	5.53s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 47.59s of the 47.58s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 47.57s of the 47.57s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 47.56s of the 47.55s of remaining time.
# 	0.9648	 = Validation accuracy score
# 	3.2s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 46.76s of the 46.75s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	23.34s	 = Training runtime
# 	1.93s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 40.7s of the 40.7s of remaining time.
# 	0.9648	 = Validation accuracy score
# 	10.34s	 = Training runtime
# 	0.05s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 37.78s of the 37.77s of remaining time.
# 	0.662	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 37.77s of the 37.76s of remaining time.
# 	0.7113	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 37.76s of the 37.75s of remaining time.
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 9: early stopping
# 	0.9859	 = Validation accuracy score
# 	27.2s	 = Training runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 32.2s of the 32.19s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	6.28s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 31.31s of the 31.3s of remaining time.
# 	0.993	 = Validation accuracy score
# 	6.28s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 29.19s of the 29.18s of remaining time.
# 	0.9859	 = Validation accuracy score
# 	0.72s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 29.18s of the 29.17s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.86s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 29.17s of the 29.16s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	6.56s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 28.11s of the 28.1s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 28.1s of the 28.09s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 28.09s of the 28.08s of remaining time.
# 	0.9577	 = Validation accuracy score
# 	3.84s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 27.32s of the 27.31s of remaining time.
# 	0.9789	 = Validation accuracy score
# 	29.23s	 = Training runtime
# 	2.52s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 20.77s of the 20.77s of remaining time.
# 	0.9648	 = Validation accuracy score
# 	12.87s	 = Training runtime
# 	0.06s	 = Validation runtime
# Completed 5/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.84s of the 18.18s of remaining time.
# 	0.993	 = Validation accuracy score
# 	0.5s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 102.36s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210619_215608/")

# %%
# Output the fit summary of the training run
predictor.fit_summary()
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L1   0.992958       0.064062   6.284373                0.064062           6.284373            1       True          5
# 1       WeightedEnsemble_L2   0.992958       0.064973   6.784873                0.000911           0.500500            2       True         14
# 2   RandomForestGini_BAG_L1   0.985915       0.105965   0.715809                0.105965           0.715809            1       True          6
# 3    NeuralNetFastAI_BAG_L1   0.985915       0.418577  27.195698                0.418577          27.195698            1       True          3
# 4           CatBoost_BAG_L1   0.978873       0.052991   6.556190                0.052991           6.556190            1       True          8
# 5         LightGBMXT_BAG_L1   0.978873       0.057510   6.283676                0.057510           6.283676            1       True          4
# 6   RandomForestEntr_BAG_L1   0.978873       0.092761   0.861414                0.092761           0.861414            1       True          7
# 7     ExtraTreesGini_BAG_L1   0.978873       0.097372   0.666157                0.097372           0.666157            1       True          9
# 8     ExtraTreesEntr_BAG_L1   0.978873       0.112253   0.652341                0.112253           0.652341            1       True         10
# 9     NeuralNetMXNet_BAG_L1   0.978873       2.524533  29.227473                2.524533          29.227473            1       True         12
# 10     LightGBMLarge_BAG_L1   0.964789       0.063712  12.867258                0.063712          12.867258            1       True         13
# 11           XGBoost_BAG_L1   0.957746       0.059339   3.841529                0.059339           3.841529            1       True         11
# 12    KNeighborsDist_BAG_L1   0.711268       0.108318   0.005929                0.108318           0.005929            1       True          2
# 13    KNeighborsUnif_BAG_L1   0.661972       0.111567   0.004244                0.111567           0.004244            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20210619_215608/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6619718309859155,
#   'KNeighborsDist_BAG_L1': 0.7112676056338029,
#   'NeuralNetFastAI_BAG_L1': 0.9859154929577465,
#   'LightGBMXT_BAG_L1': 0.9788732394366197,
#   'LightGBM_BAG_L1': 0.9929577464788732,
#   'RandomForestGini_BAG_L1': 0.9859154929577465,
#   'RandomForestEntr_BAG_L1': 0.9788732394366197,
#   'CatBoost_BAG_L1': 0.9788732394366197,
#   'ExtraTreesGini_BAG_L1': 0.9788732394366197,
#   'ExtraTreesEntr_BAG_L1': 0.9788732394366197,
#   'XGBoost_BAG_L1': 0.9577464788732394,
#   'NeuralNetMXNet_BAG_L1': 0.9788732394366197,
#   'LightGBMLarge_BAG_L1': 0.9647887323943662,
#   'WeightedEnsemble_L2': 0.9929577464788732},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/KNeighborsDist_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/NeuralNetFastAI_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/LightGBM_BAG_L1/',
#   'RandomForestGini_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/RandomForestGini_BAG_L1/',
#   'RandomForestEntr_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/RandomForestEntr_BAG_L1/',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/CatBoost_BAG_L1/',
#   'ExtraTreesGini_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/ExtraTreesGini_BAG_L1/',
#   'ExtraTreesEntr_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/ExtraTreesEntr_BAG_L1/',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/XGBoost_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/NeuralNetMXNet_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20210619_215608/models/LightGBMLarge_BAG_L1/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20210619_215608/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.004244089126586914,
#   'KNeighborsDist_BAG_L1': 0.005928993225097656,
#   'NeuralNetFastAI_BAG_L1': 27.195698261260986,
#   'LightGBMXT_BAG_L1': 6.283676385879517,
#   'LightGBM_BAG_L1': 6.284372806549072,
#   'RandomForestGini_BAG_L1': 0.7158088684082031,
#   'RandomForestEntr_BAG_L1': 0.8614139556884766,
#   'CatBoost_BAG_L1': 6.556190013885498,
#   'ExtraTreesGini_BAG_L1': 0.6661567687988281,
#   'ExtraTreesEntr_BAG_L1': 0.6523408889770508,
#   'XGBoost_BAG_L1': 3.84152889251709,
#   'NeuralNetMXNet_BAG_L1': 29.227473258972168,
#   'LightGBMLarge_BAG_L1': 12.867257595062256,
#   'WeightedEnsemble_L2': 0.500499963760376},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.11156678199768066,
#   'KNeighborsDist_BAG_L1': 0.10831785202026367,
#   'NeuralNetFastAI_BAG_L1': 0.4185769557952881,
#   'LightGBMXT_BAG_L1': 0.0575098991394043,
#   'LightGBM_BAG_L1': 0.06406235694885254,
#   'RandomForestGini_BAG_L1': 0.10596489906311035,
#   'RandomForestEntr_BAG_L1': 0.09276080131530762,
#   'CatBoost_BAG_L1': 0.052991390228271484,
#   'ExtraTreesGini_BAG_L1': 0.09737205505371094,
#   'ExtraTreesEntr_BAG_L1': 0.11225295066833496,
#   'XGBoost_BAG_L1': 0.05933856964111328,
#   'NeuralNetMXNet_BAG_L1': 2.5245327949523926,
#   'LightGBMLarge_BAG_L1': 0.06371188163757324,
#   'WeightedEnsemble_L2': 0.0009109973907470703},
#  'num_bag_folds': 5,
#  'max_stack_level': 2,
#  'num_classes': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetMXNet_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val  pred_time_val   fit_time  \
#  0           LightGBM_BAG_L1   0.992958       0.064062   6.284373
#  1       WeightedEnsemble_L2   0.992958       0.064973   6.784873
#  2   RandomForestGini_BAG_L1   0.985915       0.105965   0.715809
#  3    NeuralNetFastAI_BAG_L1   0.985915       0.418577  27.195698
#  4           CatBoost_BAG_L1   0.978873       0.052991   6.556190
#  5         LightGBMXT_BAG_L1   0.978873       0.057510   6.283676
#  6   RandomForestEntr_BAG_L1   0.978873       0.092761   0.861414
#  7     ExtraTreesGini_BAG_L1   0.978873       0.097372   0.666157
#  8     ExtraTreesEntr_BAG_L1   0.978873       0.112253   0.652341
#  9     NeuralNetMXNet_BAG_L1   0.978873       2.524533  29.227473
#  10     LightGBMLarge_BAG_L1   0.964789       0.063712  12.867258
#  11           XGBoost_BAG_L1   0.957746       0.059339   3.841529
#  12    KNeighborsDist_BAG_L1   0.711268       0.108318   0.005929
#  13    KNeighborsUnif_BAG_L1   0.661972       0.111567   0.004244
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.064062           6.284373            1       True
#  1                 0.000911           0.500500            2       True
#  2                 0.105965           0.715809            1       True
#  3                 0.418577          27.195698            1       True
#  4                 0.052991           6.556190            1       True
#  5                 0.057510           6.283676            1       True
#  6                 0.092761           0.861414            1       True
#  7                 0.097372           0.666157            1       True
#  8                 0.112253           0.652341            1       True
#  9                 2.524533          29.227473            1       True
#  10                0.063712          12.867258            1       True
#  11                0.059339           3.841529            1       True
#  12                0.108318           0.005929            1       True
#  13                0.111567           0.004244            1       True
#
#      fit_order
#  0           5
#  1          14
#  2           6
#  3           3
#  4           8
#  5           4
#  6           7
#  7           9
#  8          10
#  9          12
#  10         13
#  11         11
#  12          2
#  13          1  }

# %%
# Output the model's `score_val` in a bar chart to compare performance
predictor.leaderboard(silent=True).plot(kind="bar", x="model", y="score_val")
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='model'>

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(df_test)
# Out:
# Evaluation: accuracy on test data: 0.9722222222222222
# Evaluations on test data:
# {
#     "accuracy": 0.9722222222222222,
#     "balanced_accuracy": 0.9791666666666666,
#     "mcc": 0.9572184238576891
# }

# %% [markdown]
# ## AutoGluon Regression

# %%
# Load in the diabetes dataset
diabetes = datasets.load_diabetes()
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the diabetes `data` dataset as a dataframe and name the columns with `feature_names`
dfd = pd.DataFrame(diabetes["data"], columns=diabetes["feature_names"])

# Include the target as well
dfd["target"] = diabetes["target"]

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
dfd_train, dfd_test = train_test_split(dfd, test_size=0.2, random_state=0)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# Since we are using a different eval_metric, we'll need to assign the problem_type
predictor = TabularPredictor(
    label="target", problem_type="regression", eval_metric="r2"
).fit(
    train_data=dfd_train,
    time_limit=120,
    presets="best_quality",
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210619_215753/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "AutogluonModels/ag-20210619_215753/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    353
# Train Data Columns: 10
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6122.05 MB
# 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 10 | ['age', 'sex', 'bmi', 'bp', 's1', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 10 | ['age', 'sex', 'bmi', 'bp', 's1', ...]
# 	0.1s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.89s of the 119.89s of remaining time.
# 	0.4248	 = Validation r2 score
# 	0.0s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.77s of the 119.77s of remaining time.
# 	0.425	 = Validation r2 score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 119.62s of the 119.61s of remaining time.
# 	0.5416	 = Validation r2 score
# 	3.53s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 116.03s of the 116.03s of remaining time.
# 	0.514	 = Validation r2 score
# 	2.71s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 113.27s of the 113.27s of remaining time.
# 	0.4667	 = Validation r2 score
# 	0.84s	 = Training runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 112.19s of the 112.19s of remaining time.
# 	0.5228	 = Validation r2 score
# 	1.76s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 110.41s of the 110.4s of remaining time.
# 	0.5022	 = Validation r2 score
# 	0.56s	 = Training runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 109.63s of the 109.63s of remaining time.
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# 	-3.749	 = Validation r2 score
# 	3.24s	 = Training runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 106.17s of the 106.17s of remaining time.
# 	0.44	 = Validation r2 score
# 	2.47s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 103.12s of the 103.12s of remaining time.
# 	0.4663	 = Validation r2 score
# 	12.26s	 = Training runtime
# 	0.55s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 90.23s of the 90.23s of remaining time.
# 	0.4569	 = Validation r2 score
# 	4.22s	 = Training runtime
# 	0.01s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 85.94s of the 85.93s of remaining time.
# 	0.4248	 = Validation r2 score
# 	0.0s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 85.92s of the 85.92s of remaining time.
# 	0.425	 = Validation r2 score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 85.91s of the 85.91s of remaining time.
# 	0.5455	 = Validation r2 score
# 	6.82s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 82.57s of the 82.56s of remaining time.
# 	0.5209	 = Validation r2 score
# 	5.18s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 80.05s of the 80.05s of remaining time.
# 	0.4667	 = Validation r2 score
# 	0.84s	 = Training runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 80.05s of the 80.04s of remaining time.
# 	0.5223	 = Validation r2 score
# 	3.42s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 78.36s of the 78.36s of remaining time.
# 	0.5022	 = Validation r2 score
# 	0.56s	 = Training runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 78.34s of the 78.34s of remaining time.
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# 	-3.7481	 = Validation r2 score
# 	5.59s	 = Training runtime
# 	0.2s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 75.87s of the 75.86s of remaining time.
# 	0.4437	 = Validation r2 score
# 	5.2s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 72.75s of the 72.75s of remaining time.
# 	0.486	 = Validation r2 score
# 	25.05s	 = Training runtime
# 	1.06s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 59.4s of the 59.39s of remaining time.
# 	0.4691	 = Validation r2 score
# 	8.5s	 = Training runtime
# 	0.03s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 55.05s of the 55.05s of remaining time.
# 	0.4248	 = Validation r2 score
# 	0.0s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 55.04s of the 55.04s of remaining time.
# 	0.425	 = Validation r2 score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 55.03s of the 55.03s of remaining time.
# 	0.5484	 = Validation r2 score
# 	10.29s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 51.52s of the 51.51s of remaining time.
# 	0.5265	 = Validation r2 score
# 	7.87s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 48.78s of the 48.78s of remaining time.
# 	0.4667	 = Validation r2 score
# 	0.84s	 = Training runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 48.76s of the 48.76s of remaining time.
# 	0.5231	 = Validation r2 score
# 	5.85s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 46.26s of the 46.26s of remaining time.
# 	0.5022	 = Validation r2 score
# 	0.56s	 = Training runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 46.25s of the 46.25s of remaining time.
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# 	-3.7475	 = Validation r2 score
# 	8.07s	 = Training runtime
# 	0.27s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 43.63s of the 43.63s of remaining time.
# 	0.4496	 = Validation r2 score
# 	8.31s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 40.15s of the 40.15s of remaining time.
# 	0.4869	 = Validation r2 score
# 	37.6s	 = Training runtime
# 	1.58s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 27.02s of the 27.02s of remaining time.
# 	0.4743	 = Validation r2 score
# 	11.07s	 = Training runtime
# 	0.04s	 = Validation runtime
# Completed 3/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.89s of the 24.38s of remaining time.
# 	0.5485	 = Validation r2 score
# 	0.72s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 96.38s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210619_215753/")

# %%
# Output the fit summary of the training run
predictor.fit_summary()
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2   0.548460       1.621675  48.615491                0.000936           0.721815            2       True         12
# 1        LightGBMXT_BAG_L1   0.548364       0.036617  10.294981                0.036617          10.294981            1       True          3
# 2          LightGBM_BAG_L1   0.526471       0.034941   7.874833                0.034941           7.874833            1       True          4
# 3          CatBoost_BAG_L1   0.523150       0.051149   5.849633                0.051149           5.849633            1       True          6
# 4     ExtraTreesMSE_BAG_L1   0.502246       0.156983   0.557852                0.156983           0.557852            1       True          7
# 5    NeuralNetMXNet_BAG_L1   0.486891       1.584123  37.598695                1.584123          37.598695            1       True         10
# 6     LightGBMLarge_BAG_L1   0.474297       0.040763  11.068958                0.040763          11.068958            1       True         11
# 7   RandomForestMSE_BAG_L1   0.466743       0.170939   0.836744                0.170939           0.836744            1       True          5
# 8           XGBoost_BAG_L1   0.449632       0.046237   8.314289                0.046237           8.314289            1       True          9
# 9    KNeighborsDist_BAG_L1   0.425036       0.106198   0.005502                0.106198           0.005502            1       True          2
# 10   KNeighborsUnif_BAG_L1   0.424829       0.104777   0.002032                0.104777           0.002032            1       True          1
# 11  NeuralNetFastAI_BAG_L1  -3.747505       0.271815   8.069987                0.271815           8.069987            1       True          8
# Number of models trained: 12
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 10 | ['age', 'sex', 'bmi', 'bp', 's1', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20210619_215753/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.4248292461020926,
#   'KNeighborsDist_BAG_L1': 0.42503554002652144,
#   'LightGBMXT_BAG_L1': 0.5483636295660447,
#   'LightGBM_BAG_L1': 0.5264710231983356,
#   'RandomForestMSE_BAG_L1': 0.4667434753086127,
#   'CatBoost_BAG_L1': 0.5231497544217285,
#   'ExtraTreesMSE_BAG_L1': 0.502246448213272,
#   'NeuralNetFastAI_BAG_L1': -3.7475046459321355,
#   'XGBoost_BAG_L1': 0.4496318529861949,
#   'NeuralNetMXNet_BAG_L1': 0.4868906446923458,
#   'LightGBMLarge_BAG_L1': 0.47429713843005417,
#   'WeightedEnsemble_L2': 0.5484595734907687},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/KNeighborsDist_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/LightGBM_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/RandomForestMSE_BAG_L1/',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/ExtraTreesMSE_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/NeuralNetFastAI_BAG_L1/',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/XGBoost_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/NeuralNetMXNet_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20210619_215753/models/LightGBMLarge_BAG_L1/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20210619_215753/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0020318031311035156,
#   'KNeighborsDist_BAG_L1': 0.005501747131347656,
#   'LightGBMXT_BAG_L1': 10.294981002807617,
#   'LightGBM_BAG_L1': 7.874833106994629,
#   'RandomForestMSE_BAG_L1': 0.8367440700531006,
#   'CatBoost_BAG_L1': 5.849632501602173,
#   'ExtraTreesMSE_BAG_L1': 0.5578522682189941,
#   'NeuralNetFastAI_BAG_L1': 8.069987297058105,
#   'XGBoost_BAG_L1': 8.31428861618042,
#   'NeuralNetMXNet_BAG_L1': 37.59869456291199,
#   'LightGBMLarge_BAG_L1': 11.068958044052124,
#   'WeightedEnsemble_L2': 0.7218151092529297},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.10477685928344727,
#   'KNeighborsDist_BAG_L1': 0.10619807243347168,
#   'LightGBMXT_BAG_L1': 0.03661680221557617,
#   'LightGBM_BAG_L1': 0.03494119644165039,
#   'RandomForestMSE_BAG_L1': 0.17093920707702637,
#   'CatBoost_BAG_L1': 0.05114889144897461,
#   'ExtraTreesMSE_BAG_L1': 0.1569831371307373,
#   'NeuralNetFastAI_BAG_L1': 0.27181458473205566,
#   'XGBoost_BAG_L1': 0.04623675346374512,
#   'NeuralNetMXNet_BAG_L1': 1.584122657775879,
#   'LightGBMLarge_BAG_L1': 0.040763139724731445,
#   'WeightedEnsemble_L2': 0.0009360313415527344},
#  'num_bag_folds': 5,
#  'max_stack_level': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetMXNet_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val  pred_time_val   fit_time  \
#  0      WeightedEnsemble_L2   0.548460       1.621675  48.615491
#  1        LightGBMXT_BAG_L1   0.548364       0.036617  10.294981
#  2          LightGBM_BAG_L1   0.526471       0.034941   7.874833
#  3          CatBoost_BAG_L1   0.523150       0.051149   5.849633
#  4     ExtraTreesMSE_BAG_L1   0.502246       0.156983   0.557852
#  5    NeuralNetMXNet_BAG_L1   0.486891       1.584123  37.598695
#  6     LightGBMLarge_BAG_L1   0.474297       0.040763  11.068958
#  7   RandomForestMSE_BAG_L1   0.466743       0.170939   0.836744
#  8           XGBoost_BAG_L1   0.449632       0.046237   8.314289
#  9    KNeighborsDist_BAG_L1   0.425036       0.106198   0.005502
#  10   KNeighborsUnif_BAG_L1   0.424829       0.104777   0.002032
#  11  NeuralNetFastAI_BAG_L1  -3.747505       0.271815   8.069987
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000936           0.721815            2       True
#  1                 0.036617          10.294981            1       True
#  2                 0.034941           7.874833            1       True
#  3                 0.051149           5.849633            1       True
#  4                 0.156983           0.557852            1       True
#  5                 1.584123          37.598695            1       True
#  6                 0.040763          11.068958            1       True
#  7                 0.170939           0.836744            1       True
#  8                 0.046237           8.314289            1       True
#  9                 0.106198           0.005502            1       True
#  10                0.104777           0.002032            1       True
#  11                0.271815           8.069987            1       True
#
#      fit_order
#  0          12
#  1           3
#  2           4
#  3           6
#  4           7
#  5          10
#  6          11
#  7           5
#  8           9
#  9           2
#  10          1
#  11          8  }

# %%
# Output the model's `score_val` in a bar chart to compare performance
predictor.leaderboard(silent=True).plot(kind="bar", x="model", y="score_val")
# Out:
# /Users/mattmaybeno/workspace/nd009t-c1-intro-to-ml/.venv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='model'>

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(dfd_test)
# Out:
# Evaluation: r2 on test data: 0.3259462109518938
# Evaluations on test data:
# {
#     "r2": 0.3259462109518938,
#     "root_mean_squared_error": -58.79199472836164,
#     "mean_squared_error": -3456.4986441397027,
#     "mean_absolute_error": -44.71294840266196,
#     "pearsonr": 0.5872170075907791,
#     "median_absolute_error": -38.157073974609375
# }
